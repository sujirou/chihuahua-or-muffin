# %%
# %matplotlib inline
from recognize_dogs import cnn_dog, categories_dog, func, recog_dogs
import matplotlib.pyplot as plt
from PIL import Image
import numpy as np

image = Image.open('sharpei2.jpg')
recog_dogs(image)
# Out:
# Loading Caffe model file bvlc_googlenet.caffemodel...
# Loaded
# #1 | tiger, Panthera tigris | 81.2%
# #2 | bull mastiff, dog |  8.7%
# #3 | tiger cat |  5.6%
# #4 | isopod |  0.9%
# #5 | potter's wheel |  0.8%
# #1 | French loaf | 99.5%
# #2 | rotisserie |  0.1%
# #3 | pretzel |  0.1%
# #4 | cowboy boot |  0.0%
# #5 | potpie |  0.0%
# #1 | chambered nautilus, pearly nautilus, nautilus | 84.9%
# #2 | bagel, beigel | 10.5%
# #3 | snail |  2.1%
# #4 | slug |  0.7%
# #5 | hen-of-the-woods, hen of the woods, Polyporus frondosus, Grifola frondosa |  0.5%
# #1 | vizsla, Hungarian pointer, dog | 73.0%
# #2 | redbone, dog | 15.8%
# #3 | Sussex spaniel, dog |  4.2%
# #4 | bloodhound, sleuthhound, dog |  2.5%
# #5 | Rhodesian ridgeback, dog |  1.8%
# #1 | wool, woolen, woollen | 25.6%
# #2 | velvet | 16.5%
# #3 | chambered nautilus, pearly nautilus, nautilus |  9.8%
# #4 | hen-of-the-woods, hen of the woods, Polyporus frondosus, Grifola frondosa |  5.3%
# #5 | custard apple |  4.6%
# ...
