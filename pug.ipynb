# %%
# %matplotlib inline
from recognize_dogs import cnn_dog, categories_dog, func
import matplotlib.pyplot as plt
from PIL import Image
import numpy as np

# %%
image = Image.open('pugs.jpg')
recog_dogs(image)
# Out:
# #1 | pug, pug-dog, dog | 98.5%
# #2 | bull mastiff, dog |  1.4%
# #3 | French bulldog, dog |  0.1%
# #4 | muzzle |  0.0%
# #5 | Brabancon griffon, dog |  0.0%
# #1 | doormat, welcome mat | 13.9%
# #2 | French loaf |  4.7%
# #3 | cockroach, roach |  4.5%
# #4 | clog, geta, patten, sabot |  4.5%
# #5 | isopod |  4.0%
# #1 | bull mastiff, dog | 52.0%
# #2 | pug, pug-dog, dog | 47.6%
# #3 | Brabancon griffon, dog |  0.2%
# #4 | bloodhound, sleuthhound, dog |  0.2%
# #5 | Leonberg, dog |  0.0%
# #1 | French loaf | 95.2%
# #2 | dough |  2.1%
# #3 | clog, geta, patten, sabot |  0.7%
# #4 | mortar |  0.4%
# #5 | wool, woolen, woollen |  0.1%
# #1 | platypus, duckbill, duckbilled platypus, duck-billed platypus, Ornithorhynchus anatinus | 29.6%
# #2 | Chesapeake Bay retriever, dog | 23.2%
# #3 | curly-coated retriever, dog | 12.6%
# #4 | Staffordshire bullterrier, Staffordshire bull terrier, dog | 10.0%
# #5 | Labrador retriever, dog |  5.9%
# #1 | French loaf | 99.5%
# ...
