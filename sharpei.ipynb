# %%
# %matplotlib inline
from recognize_dogs import cnn_dog, categories_dog, func, recog_dogs
import matplotlib.pyplot as plt
from PIL import Image
import numpy as np

image = Image.open('sharpei.jpg')
recog_dogs(image)
# Out:
# Loading Caffe model file bvlc_googlenet.caffemodel...
# Loaded
# #1 | wool, woolen, woollen | 75.0%
# #2 | bath towel | 10.2%
# #3 | knot |  1.7%
# #4 | nipple |  1.5%
# #5 | dough |  1.2%
# #1 | bagel, beigel | 35.9%
# #2 | French loaf | 15.3%
# #3 | horned viper, cerastes, sand viper, horned asp, Cerastes cornutus | 10.0%
# #4 | wool, woolen, woollen |  7.1%
# #5 | sidewinder, horned rattlesnake, Crotalus cerastes |  4.8%
# #1 | Chesapeake Bay retriever, dog | 49.6%
# #2 | bloodhound, sleuthhound, dog | 17.9%
# #3 | bull mastiff, dog | 13.6%
# #4 | vizsla, Hungarian pointer, dog |  4.2%
# #5 | Rhodesian ridgeback, dog |  2.0%
# #1 | wool, woolen, woollen | 31.5%
# #2 | paper towel | 22.8%
# #3 | bath towel | 19.4%
# #4 | velvet |  4.2%
# #5 | quilt, comforter, comfort, puff |  2.8%
# #1 | bull mastiff, dog | 46.8%
# #2 | bloodhound, sleuthhound, dog | 44.1%
# #3 | pug, pug-dog, dog |  1.6%
# #4 | soft-coated wheaten terrier, dog |  0.8%
# #5 | fur coat |  0.7%
# #1 | gyromitra | 38.8%
# #2 | hen-of-the-woods, hen of the woods, Polyporus frondosus, Grifola frondosa | 23.1%
# #3 | velvet | 16.6%
# #4 | triceratops |  8.9%
# #5 | butcher shop, meat market |  2.0%
# #1 | bull mastiff, dog | 61.2%
# #2 | Chesapeake Bay retriever, dog | 14.5%
# #3 | bloodhound, sleuthhound, dog |  7.7%
# #4 | Indian elephant, Elephas maximus |  3.1%
# #5 | vizsla, Hungarian pointer, dog |  1.9%
# #1 | Band Aid | 16.7%
# #2 | paper towel | 12.0%
# #3 | bath towel | 10.3%
# #4 | knee pad |  9.4%
# #5 | wool, woolen, woollen |  9.2%
# #1 | bull mastiff, dog | 98.8%
# #2 | clumber, clumber spaniel, dog |  0.4%
# #3 | American Staffordshire terrier, Staffordshire terrier, American pit bull terrier, pit bull terrier, dog |  0.3%
# #4 | bloodhound, sleuthhound, dog |  0.1%
# #5 | French bulldog, dog |  0.1%
# #1 | horned viper, cerastes, sand viper, horned asp, Cerastes cornutus | 17.9%
# #2 | chain mail, ring mail, mail, chain armor, chain armour, ring armor, ring armour |  9.9%
# #3 | Indian cobra, Naja naja |  9.4%
# #4 | rock python, rock snake, Python sebae |  8.7%
# #5 | sidewinder, horned rattlesnake, Crotalus cerastes |  7.9%
# #1 | wool, woolen, woollen | 52.0%
# #2 | velvet | 38.0%
# #3 | bath towel |  2.8%
# #4 | knot |  1.0%
# #5 | nematode, nematode worm, roundworm |  0.7%
# #1 | French loaf | 31.3%
# #2 | horned viper, cerastes, sand viper, horned asp, Cerastes cornutus | 25.1%
# #3 | bagel, beigel |  8.2%
# #4 | dough |  7.5%
# #5 | knot |  5.2%
