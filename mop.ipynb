# %%
# %matplotlib inline
from recognize_dogs import cnn_dog, categories_dog, func, recog_dogs
import matplotlib.pyplot as plt
from PIL import Image
import numpy as np

image = Image.open('mop.jpg')
recog_dogs(image)
# Out:
# Loading Caffe model file bvlc_googlenet.caffemodel...
# Loaded
# #1 | komondor, dog | 100.0%
# #2 | otterhound, otter hound, dog |  0.0%
# #3 | briard, dog |  0.0%
# #4 | Tibetan terrier, chrysanthemum dog, dog |  0.0%
# #5 | Old English sheepdog, bobtail, dog |  0.0%
# #1 | komondor, dog | 91.2%
# #2 | swab, swob, mop |  8.6%
# #3 | wool, woolen, woollen |  0.2%
# #4 | hen-of-the-woods, hen of the woods, Polyporus frondosus, Grifola frondosa |  0.0%
# #5 | knot |  0.0%
# #1 | komondor, dog | 100.0%
# #2 | wool, woolen, woollen |  0.0%
# #3 | swab, swob, mop |  0.0%
# #4 | kuvasz, dog |  0.0%
# #5 | mitten |  0.0%
# #1 | komondor, dog | 98.7%
# #2 | swab, swob, mop |  1.1%
# #3 | wool, woolen, woollen |  0.2%
# #4 | kuvasz, dog |  0.0%
# #5 | African grey, African gray, Psittacus erithacus |  0.0%
# #1 | komondor, dog | 100.0%
# #2 | swab, swob, mop |  0.0%
# #3 | Tibetan terrier, chrysanthemum dog, dog |  0.0%
# #4 | otterhound, otter hound, dog |  0.0%
# ...
