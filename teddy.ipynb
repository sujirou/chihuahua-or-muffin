# %%
# %matplotlib inline
from recognize_dogs import cnn_dog, categories_dog, func, recog_dogs
import matplotlib.pyplot as plt
from PIL import Image
import numpy as np

image = Image.open('teddy.jpg')
recog_dogs(image)
# Out:
# Loading Caffe model file bvlc_googlenet.caffemodel...
# Loaded
# #1 | teddy, teddy bear | 99.8%
# #2 | toyshop |  0.1%
# #3 | wool, woolen, woollen |  0.0%
# #4 | bonnet, poke bonnet |  0.0%
# #5 | Airedale, Airedale terrier, dog |  0.0%
# #1 | teddy, teddy bear | 95.4%
# #2 | toy poodle, dog |  2.4%
# #3 | miniature poodle, dog |  1.3%
# #4 | Bedlington terrier, dog |  0.2%
# #5 | wool, woolen, woollen |  0.1%
# #1 | toy poodle, dog | 67.6%
# #2 | miniature poodle, dog | 31.4%
# #3 | Airedale, Airedale terrier, dog |  0.3%
# #4 | standard poodle, dog |  0.3%
# #5 | Lakeland terrier, dog |  0.2%
# #1 | dough | 26.0%
# #2 | French loaf | 25.8%
# #3 | earthstar | 11.2%
# #4 | hen-of-the-woods, hen of the woods, Polyporus frondosus, Grifola frondosa |  7.2%
# #5 | teddy, teddy bear |  6.8%
# #1 | toy poodle, dog | 74.0%
# #2 | miniature poodle, dog | 23.2%
# #3 | teddy, teddy bear |  2.4%
# #4 | standard poodle, dog |  0.1%
# #5 | Airedale, Airedale terrier, dog |  0.1%
# #1 | miniature poodle, dog | 51.1%
# #2 | toy poodle, dog | 47.8%
# #3 | standard poodle, dog |  0.5%
# #4 | Norwich terrier, dog |  0.2%
# #5 | Lakeland terrier, dog |  0.1%
# #1 | toy poodle, dog | 68.8%
# #2 | miniature poodle, dog | 30.8%
# #3 | standard poodle, dog |  0.1%
# #4 | Norwich terrier, dog |  0.1%
# #5 | Yorkshire terrier, dog |  0.0%
# #1 | teddy, teddy bear | 99.9%
# #2 | wool, woolen, woollen |  0.0%
# #3 | toyshop |  0.0%
# #4 | toy poodle, dog |  0.0%
# #5 | miniature poodle, dog |  0.0%
