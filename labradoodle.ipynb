# %%
# %matplotlib inline
from recognize_dogs import cnn_dog, categories_dog, func, recog_dogs
import matplotlib.pyplot as plt
from PIL import Image
import numpy as np

image = Image.open('labradoodle.jpg')
recog_dogs(image)
# Out:
# Loading Caffe model file bvlc_googlenet.caffemodel...
# Loaded
# #1 | komondor, dog | 27.0%
# #2 | miniature poodle, dog | 16.7%
# #3 | toy poodle, dog | 13.9%
# #4 | cocker spaniel, English cocker spaniel, cocker, dog | 11.8%
# #5 | standard poodle, dog |  4.3%
# #1 | Sussex spaniel, dog | 43.1%
# #2 | otterhound, otter hound, dog | 34.5%
# #3 | miniature poodle, dog |  8.6%
# #4 | Irish water spaniel, dog |  4.1%
# #5 | cocker spaniel, English cocker spaniel, cocker, dog |  2.4%
# #1 | meat loaf, meatloaf | 46.5%
# #2 | French loaf | 35.6%
# #3 | potpie |  7.0%
# #4 | bagel, beigel |  2.8%
# #5 | dough |  2.1%
# #1 | French loaf | 35.0%
# #2 | meat loaf, meatloaf | 20.3%
# #3 | potpie | 17.6%
# #4 | gyromitra |  5.1%
# #5 | fig |  3.7%
# #1 | meat loaf, meatloaf | 57.2%
# #2 | hen-of-the-woods, hen of the woods, Polyporus frondosus, Grifola frondosa | 13.4%
# #3 | gyromitra |  6.7%
# #4 | potpie |  4.4%
# #5 | plate |  4.0%
# #1 | miniature poodle, dog | 36.7%
# ...
